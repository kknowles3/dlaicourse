# %%
import json
import tensorflow as tf
import numpy as np

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json \
    -O /tmp/sarcasm.json

vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000


with open("/tmp/sarcasm.json", 'r') as f:
    datastore = json.load(f)


sentences = []
labels = []
urls = []
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

print(training_labels[:5])
print(testing_labels[:5])

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(type(training_padded))

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 50
history = model.fit(training_padded, np.array(training_labels), epochs=num_epochs, validation_data=(testing_padded, np.array(testing_labels)), verbose=1)
# Out:
# --2020-04-08 16:04:08--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.97.128, 2404:6800:4008:c06::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.97.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘/tmp/sarcasm.json’
#
# /tmp/sarcasm.json   100%[===================>]   5.38M  --.-KB/s    in 0.05s
#
# 2020-04-08 16:04:08 (118 MB/s) - ‘/tmp/sarcasm.json’ saved [5643545/5643545]
#
# [0, 0, 1, 1, 0]
# [1, 0, 0, 1, 0]
# <class 'numpy.ndarray'>
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 120, 16)           16000
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 116, 128)          10368
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 24)                3096
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 25
# =================================================================
# Total params: 29,489
# Trainable params: 29,489
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4813 - accuracy: 0.7563 - val_loss: 0.4045 - val_accuracy: 0.8189
# Epoch 2/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3609 - accuracy: 0.8404 - val_loss: 0.3963 - val_accuracy: 0.8204
# Epoch 3/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3228 - accuracy: 0.8564 - val_loss: 0.3897 - val_accuracy: 0.8216
# Epoch 4/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.2898 - accuracy: 0.8743 - val_loss: 0.4169 - val_accuracy: 0.8153
# Epoch 5/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.2590 - accuracy: 0.8897 - val_loss: 0.4259 - val_accuracy: 0.8162
# Epoch 6/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.2266 - accuracy: 0.9064 - val_loss: 0.4531 - val_accuracy: 0.8168
# Epoch 7/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.2000 - accuracy: 0.9183 - val_loss: 0.4931 - val_accuracy: 0.8153
# Epoch 8/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.1670 - accuracy: 0.9342 - val_loss: 0.5610 - val_accuracy: 0.8103
# Epoch 9/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.1412 - accuracy: 0.9459 - val_loss: 0.6036 - val_accuracy: 0.8080
# Epoch 10/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.1168 - accuracy: 0.9572 - val_loss: 0.6737 - val_accuracy: 0.8027
# Epoch 11/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0975 - accuracy: 0.9651 - val_loss: 0.7717 - val_accuracy: 0.7961
# Epoch 12/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0796 - accuracy: 0.9725 - val_loss: 0.8176 - val_accuracy: 0.8022
# Epoch 13/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0690 - accuracy: 0.9760 - val_loss: 0.8953 - val_accuracy: 0.8001
# Epoch 14/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0612 - accuracy: 0.9788 - val_loss: 1.0256 - val_accuracy: 0.7962
# Epoch 15/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0524 - accuracy: 0.9825 - val_loss: 1.0460 - val_accuracy: 0.7983
# Epoch 16/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0472 - accuracy: 0.9825 - val_loss: 1.1447 - val_accuracy: 0.7913
# Epoch 17/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0447 - accuracy: 0.9832 - val_loss: 1.2414 - val_accuracy: 0.7916
# Epoch 18/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0380 - accuracy: 0.9859 - val_loss: 1.3164 - val_accuracy: 0.7988
# Epoch 19/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0366 - accuracy: 0.9865 - val_loss: 1.3467 - val_accuracy: 0.7910
# Epoch 20/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0389 - accuracy: 0.9854 - val_loss: 1.3867 - val_accuracy: 0.7928
# Epoch 21/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0374 - accuracy: 0.9858 - val_loss: 1.4476 - val_accuracy: 0.7924
# Epoch 22/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0307 - accuracy: 0.9888 - val_loss: 1.6504 - val_accuracy: 0.7880
# Epoch 23/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0278 - accuracy: 0.9886 - val_loss: 1.5453 - val_accuracy: 0.7916
# Epoch 24/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0253 - accuracy: 0.9897 - val_loss: 1.5931 - val_accuracy: 0.7874
# Epoch 25/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0286 - accuracy: 0.9888 - val_loss: 1.5878 - val_accuracy: 0.7919
# Epoch 26/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0269 - accuracy: 0.9894 - val_loss: 1.9196 - val_accuracy: 0.7806
# Epoch 27/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0320 - accuracy: 0.9880 - val_loss: 1.7534 - val_accuracy: 0.7880
# Epoch 28/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0299 - accuracy: 0.9878 - val_loss: 1.7103 - val_accuracy: 0.7849
# Epoch 29/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0289 - accuracy: 0.9880 - val_loss: 1.8361 - val_accuracy: 0.7936
# Epoch 30/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0235 - accuracy: 0.9900 - val_loss: 1.8705 - val_accuracy: 0.7952
# Epoch 31/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0217 - accuracy: 0.9911 - val_loss: 1.9881 - val_accuracy: 0.7848
# Epoch 32/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0222 - accuracy: 0.9911 - val_loss: 1.8771 - val_accuracy: 0.7956
# Epoch 33/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0218 - accuracy: 0.9905 - val_loss: 1.9868 - val_accuracy: 0.7952
# Epoch 34/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0279 - accuracy: 0.9880 - val_loss: 2.1271 - val_accuracy: 0.7930
# Epoch 35/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0255 - accuracy: 0.9897 - val_loss: 2.2527 - val_accuracy: 0.7806
# Epoch 36/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0235 - accuracy: 0.9896 - val_loss: 2.0397 - val_accuracy: 0.7918
# Epoch 37/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0196 - accuracy: 0.9919 - val_loss: 2.1316 - val_accuracy: 0.7921
# Epoch 38/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0202 - accuracy: 0.9912 - val_loss: 2.2244 - val_accuracy: 0.7874
# Epoch 39/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0199 - accuracy: 0.9916 - val_loss: 2.1060 - val_accuracy: 0.7891
# Epoch 40/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0224 - accuracy: 0.9908 - val_loss: 2.1354 - val_accuracy: 0.7872
# Epoch 41/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0236 - accuracy: 0.9904 - val_loss: 2.2313 - val_accuracy: 0.7867
# Epoch 42/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0229 - accuracy: 0.9908 - val_loss: 2.2405 - val_accuracy: 0.7898
# Epoch 43/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0241 - accuracy: 0.9897 - val_loss: 2.2555 - val_accuracy: 0.7885
# Epoch 44/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0197 - accuracy: 0.9910 - val_loss: 2.3920 - val_accuracy: 0.7793
# Epoch 45/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0193 - accuracy: 0.9922 - val_loss: 2.3885 - val_accuracy: 0.7854
# Epoch 46/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0172 - accuracy: 0.9925 - val_loss: 2.3019 - val_accuracy: 0.7825
# Epoch 47/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0177 - accuracy: 0.9921 - val_loss: 2.7196 - val_accuracy: 0.7858
# Epoch 48/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0215 - accuracy: 0.9908 - val_loss: 2.4715 - val_accuracy: 0.7913
# Epoch 49/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0233 - accuracy: 0.9901 - val_loss: 2.4096 - val_accuracy: 0.7907
# Epoch 50/50
# 625/625 [==============================] - 4s 6ms/step - loss: 0.0218 - accuracy: 0.9908 - val_loss: 2.5145 - val_accuracy: 0.7845

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
model.save("test.h5")
